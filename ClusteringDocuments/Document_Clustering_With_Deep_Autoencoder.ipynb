# %% [markdown]
# # Text Clustering Using Auto Encoders
#
# Reference:
# This work is inspired by the blog posted by Chengwei titled: ["How to do Unsupervised Clustering with Keras"](https://github.com/Tony607/Keras_Deep_Clustering/blob/master/Keras-DEC.ipynb)
#
# This work will be comprise of the following tasks:
#   - Use the [20 News Group](https://scikit-learn.org/0.18/auto_examples/text/document_clustering.html) data and K-means evaluation provided by Sci Kit Learn
#   - Use K-means as a base-line model for computing the clusters in 20 New Group data
#   - Extended the K-means model to use the Autoencoder keras based model to improve the prediction of the clusters
#   - Visualization of the clusters using T-SNE
#   - Evaluation of the models performance metrics

# %% [markdown]
# ## Mount my working drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Install mpld3 to create interactive matplotlib graphics

# %%
# !pip install git+git://github.com/mpld3/mpld3@master#egg=mpld3
# !pip install MulticoreTSNE-modified
# !pip install tensorflow==1.14
# Out:
# Requirement already satisfied: mpld3 from git+git://github.com/mpld3/mpld3@master#egg=mpld3 in /usr/local/lib/python3.6/dist-packages (0.3.1.dev1)
# Requirement already satisfied: MulticoreTSNE-modified in /usr/local/lib/python3.6/dist-packages (0.1.post2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from MulticoreTSNE-modified) (1.14.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from MulticoreTSNE-modified) (1.18.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.6/dist-packages (from MulticoreTSNE-modified) (3.12.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->MulticoreTSNE-modified) (2.20)
# Requirement already satisfied: tensorflow==1.14 in /usr/local/lib/python3.6/dist-packages (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.18.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.28.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.34.2)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.9.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (3.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.12.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.2.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (46.1.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)

# %% [markdown]
# ## Imports

# %%
import mpld3
import sys
sys.path.insert(0,'/content/drive/My Drive/Colab Notebooks/TextClustering/ClusteringDocuments')

# %%
import RunDocClustering as rdc
import Constants as c

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## Run Baseline Model using K-means with no dimensionality reduction

# %%
def demoNoDimReductionKmeansModel():
  c.IS_KMEANS_MODEL = True
  c.IS_AUTOENCODER_MODEL = False
  c.IS_APPLY_LSA_DIM_REDUCTION = False
  return rdc.run()

fig = demoNoDimReductionKmeansModel()
mpld3.display(fig)
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# In isDataExist()..
# Loading 20 newsgroups dataset for categories:
# ['alt.atheism', 'comp.graphics', 'talk.religion.misc', 'sci.space']
# There are 3387 documents
# There are 4 categories
#
# X.shape post-TFIDF is: (3387, 10000)
# Run time of this operation is: 13.31 seconds
# n_samples: 3387, n_features: 10000
#
# data_results[X].shape: (3387, 10000)
# Starting to compute the K-means clustering algorithm..
# Run time of this operation is: 0.08 seconds
# Saving model to cache path: Cache_kmeans_model.pl
# ------------------------------------------------------------
# Top terms per cluster:
# cluster_to_label_map: {0: 'alt.atheism', 2: 'comp.graphics', 3: 'sci.space', 1: 'talk.religion.misc'}
# Cluster [0 alt.atheism]: god com jesus sandvik people bible don christian article just
# Cluster [2 comp.graphics]: space access nasa henry digex pat com toronto alaska gov
# Cluster [3 sci.space]: graphics university image thanks com ac posting host nntp files
# Cluster [1 talk.religion.misc]: keith sgi caltech com morality livesey objective moral solntze wpd
# ------------------------------------------------------------
# K-means prediction accuracy is: 0.36
# K-means prediction homogeniety score is: 0.55
# ------------------------------------------------------------
#
#
# Clustering Results:
# +----+----------------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                             |   predicted_clusters |   actual_clusters |
# |----+----------------------------------------------------------------------------------+----------------------+-------------------|
# |  1 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/54166        |                    0 |                 0 |
# |  9 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/84569  |                    0 |                 3 |
# | 11 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53784         |                    0 |                 0 |
# | 12 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/54184         |                    0 |                 0 |
# | 13 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/83506 |                    0 |                 3 |
# | 16 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53754        |                    0 |                 0 |
# | 20 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/84248  |                    0 |                 3 |
# | 24 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/83897 |                    0 |                 3 |
# | 30 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/83438 |                    0 |                 3 |
# | 31 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/84055 |                    0 |                 3 |
# +----+----------------------------------------------------------------------------------+----------------------+-------------------+
# +----+---------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                      |   predicted_clusters |   actual_clusters |
# |----+---------------------------------------------------------------------------+----------------------+-------------------|
# |  0 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51286 |                    1 |                 0 |
# |  5 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53522 |                    1 |                 0 |
# | 14 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53627  |                    1 |                 0 |
# | 21 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53212 |                    1 |                 0 |
# | 25 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53398  |                    1 |                 0 |
# | 28 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51310 |                    1 |                 0 |
# | 52 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51178 |                    1 |                 0 |
# | 58 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53120 |                    1 |                 0 |
# | 62 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53346  |                    1 |                 0 |
# | 65 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53059 |                    1 |                 0 |
# +----+---------------------------------------------------------------------------+----------------------+-------------------+
# +----+-------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                    |   predicted_clusters |   actual_clusters |
# |----+-------------------------------------------------------------------------+----------------------+-------------------|
# |  2 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61019 |                    2 |                 2 |
# |  6 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61395  |                    2 |                 2 |
# |  7 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/59850 |                    2 |                 2 |
# | 10 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60223 |                    2 |                 2 |
# | 15 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61170 |                    2 |                 2 |
# | 19 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60861 |                    2 |                 2 |
# | 22 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61253  |                    2 |                 2 |
# | 23 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61017 |                    2 |                 2 |
# | 27 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60910 |                    2 |                 2 |
# | 32 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60770 |                    2 |                 2 |
# +----+-------------------------------------------------------------------------+----------------------+-------------------+
# +----+---------------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                            |   predicted_clusters |   actual_clusters |
# |----+---------------------------------------------------------------------------------+----------------------+-------------------|
# |  3 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/83968 |                    3 |                 3 |
# |  4 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60921         |                    3 |                 2 |
# |  8 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61004         |                    3 |                 2 |
# | 17 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38396     |                    3 |                 1 |
# | 18 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38424     |                    3 |                 1 |
# | 26 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38286     |                    3 |                 1 |
# | 29 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53806        |                    3 |                 0 |
# | 36 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51151       |                    3 |                 0 |
# | 41 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38360     |                    3 |                 1 |
# | 45 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61523          |                    3 |                 2 |
# +----+---------------------------------------------------------------------------------+----------------------+-------------------+
#
#
# dist.shape: (3387, 3387)
# Plotting the clusters in 2D space..
# <style>
#
# </style>
#
# <div id="fig_el1211405180648522168906946011"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1211405180648522168906946011", {"width": 1224.0, "height": 648.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-49.52595372586447, 52.05585194554452], "ylim": [-64.66601518792814, 56.828807240273825], "xdomain": [-49.52595372586447, 52.05585194554452], "ydomain": [-64.66601518792814, 56.828807240273825], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el121140518064873936", "lines": [], "paths": [{"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el121140518065033288", "dasharray": "none", "alpha": 0.8, "facecolor": "#FFFFFF", "edgecolor": "#CCCCCC", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el121140518065034968pts", "facecolor": "#1B9E77", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001], [-5.36780214952945, 3.117479224709121], [-4.242640687119286, 4.242640687119286], [-3.117479224709121, 5.36780214952945], [-1.5912186000000001, 6.0], [0.0, 6.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el121140518065034016pts", "facecolor": "#D95F02", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001], [-5.36780214952945, 3.117479224709121], [-4.242640687119286, 4.242640687119286], [-3.117479224709121, 5.36780214952945], [-1.5912186000000001, 6.0], [0.0, 6.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el121140518065036928pts", "facecolor": "#7570B3", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001],  ...

# %% [markdown]
# ## Run Model using K-means with dimensionality reduction

# %%
def demoWithDimReductionKmeansModel():
  c.IS_KMEANS_MODEL = True
  c.IS_AUTOENCODER_MODEL = False
  c.IS_USE_TSNE = True
  c.IS_APPLY_LSA_DIM_REDUCTION = True
  return rdc.run()

fig = demoWithDimReductionKmeansModel()
mpld3.display(fig)
# Out:
# In isDataExist()..
# Loading 20 newsgroups dataset for categories:
# ['alt.atheism', 'comp.graphics', 'talk.religion.misc', 'sci.space']
# There are 3387 documents
# There are 4 categories
#
# X.shape post-TFIDF is: (3387, 10000)
# Run time of this operation is: 0.90 seconds
# n_samples: 3387, n_features: 10000
#
# Starting to perform dimensionality reduction using LSA
# Run time for LSA processing operation is: 0.13 seconds
# X.shape post-SVD is: (3387, 4)
# data_results[X].shape: (3387, 4)
# Starting to compute the K-means clustering algorithm..
# Run time of this operation is: 0.03 seconds
# Saving model to cache path: Cache_kmeans_model_with_reduced_dim.pl
# ------------------------------------------------------------
# Top terms per cluster:
# cluster_to_label_map: {0: 'alt.atheism', 2: 'comp.graphics', 3: 'sci.space', 1: 'talk.religion.misc'}
# Cluster [0 alt.atheism]: god com sandvik people don jesus article think sgi say
# Cluster [2 comp.graphics]: graphics space image university nasa ac program uk posting like
# Cluster [3 sci.space]: henry toronto space access digex zoo nasa pat spencer alaska
# Cluster [1 talk.religion.misc]: space henry nasa access com toronto like digex gov article
# ------------------------------------------------------------
# K-means prediction accuracy is: 0.26
# K-means prediction homogeniety score is: 0.59
# ------------------------------------------------------------
#
#
# Clustering Results:
# +----+----------------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                             |   predicted_clusters |   actual_clusters |
# |----+----------------------------------------------------------------------------------+----------------------+-------------------|
# |  0 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51286        |                    0 |                 0 |
# |  1 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/54166        |                    0 |                 0 |
# |  5 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53522        |                    0 |                 0 |
# |  9 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/84569  |                    0 |                 3 |
# | 11 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53784         |                    0 |                 0 |
# | 12 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/54184         |                    0 |                 0 |
# | 13 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/83506 |                    0 |                 3 |
# | 14 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53627         |                    0 |                 0 |
# | 16 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53754        |                    0 |                 0 |
# | 20 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/84248  |                    0 |                 3 |
# +----+----------------------------------------------------------------------------------+----------------------+-------------------+
# +----+---------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                      |   predicted_clusters |   actual_clusters |
# |----+---------------------------------------------------------------------------+----------------------+-------------------|
# |  4 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60921   |                    1 |                 2 |
# |  6 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61395    |                    1 |                 2 |
# |  7 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/59850   |                    1 |                 2 |
# |  8 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61004   |                    1 |                 2 |
# | 15 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61170   |                    1 |                 2 |
# | 22 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61253    |                    1 |                 2 |
# | 32 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60770   |                    1 |                 2 |
# | 36 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51151 |                    1 |                 0 |
# | 44 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60929   |                    1 |                 2 |
# | 45 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61523    |                    1 |                 2 |
# +----+---------------------------------------------------------------------------+----------------------+-------------------+
# +----+---------------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                            |   predicted_clusters |   actual_clusters |
# |----+---------------------------------------------------------------------------------+----------------------+-------------------|
# |  3 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/83968 |                    2 |                 3 |
# | 17 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38396     |                    2 |                 1 |
# | 18 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38424     |                    2 |                 1 |
# | 26 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38286     |                    2 |                 1 |
# | 29 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53806        |                    2 |                 0 |
# | 41 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38360     |                    2 |                 1 |
# | 47 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38574     |                    2 |                 1 |
# | 48 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38472     |                    2 |                 1 |
# | 50 | /root/scikit_learn_data/20news_home/20news-bydate-test/comp.graphics/38959      |                    2 |                 1 |
# | 54 | /root/scikit_learn_data/20news_home/20news-bydate-test/comp.graphics/39035      |                    2 |                 1 |
# +----+---------------------------------------------------------------------------------+----------------------+-------------------+
# +----+-------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                    |   predicted_clusters |   actual_clusters |
# |----+-------------------------------------------------------------------------+----------------------+-------------------|
# |  2 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61019 |                    3 |                 2 |
# | 10 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60223 |                    3 |                 2 |
# | 19 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60861 |                    3 |                 2 |
# | 23 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61017 |                    3 |                 2 |
# | 27 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60910 |                    3 |                 2 |
# | 33 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61337  |                    3 |                 2 |
# | 34 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60808 |                    3 |                 2 |
# | 35 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61478  |                    3 |                 2 |
# | 39 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60862 |                    3 |                 2 |
# | 40 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61045 |                    3 |                 2 |
# +----+-------------------------------------------------------------------------+----------------------+-------------------+
#
#
# dist.shape: (3387, 3387)
# Plotting the clusters in 2D space..
# <style>
#
# </style>
#
# <div id="fig_el121140518058717872380049316"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el121140518058717872380049316", {"width": 1224.0, "height": 648.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-37.863292347050525, 39.996125120838244], "ylim": [-48.37722480072915, 47.399346499053216], "xdomain": [-37.863292347050525, 39.996125120838244], "ydomain": [-48.37722480072915, 47.399346499053216], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 9, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el121140518065239824", "lines": [], "paths": [{"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el121140518058276568", "dasharray": "none", "alpha": 0.8, "facecolor": "#FFFFFF", "edgecolor": "#CCCCCC", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el121140518058275056pts", "facecolor": "#1B9E77", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001], [-5.36780214952945, 3.117479224709121], [-4.242640687119286, 4.242640687119286], [-3.117479224709121, 5.36780214952945], [-1.5912186000000001, 6.0], [0.0, 6.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el121140518058276064pts", "facecolor": "#D95F02", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001], [-5.36780214952945, 3.117479224709121], [-4.242640687119286, 4.242640687119286], [-3.117479224709121, 5.36780214952945], [-1.5912186000000001, 6.0], [0.0, 6.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el121140518058278472pts", "facecolor": "#7570B3", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001 ...

# %% [markdown]
# ## Run Autoencoder clustering Model

# %%
def demoWithAutoencoderClusteringModel():
  c.IS_KMEANS_MODEL = False
  c.IS_APPLY_LSA_DIM_REDUCTION = False
  c.IS_AUTOENCODER_MODEL = True
  return rdc.run()

fig = demoWithAutoencoderClusteringModel()
mpld3.display(fig)
# Out:
# In isDataExist()..
# Pre-process data already exists and will be obtained from the cache path: Cache_pre_process_data.pl
# Run time of this operation is: 0.00 seconds
# data_results[X].shape: (3387, 10000)
# X.shape: (3387, 10000)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 5000)              50005000
# _________________________________________________________________
# dense_2 (Dense)              (None, 2500)              12502500
# _________________________________________________________________
# dense_3 (Dense)              (None, 1250)              3126250
# _________________________________________________________________
# embedding (Dense)            (None, 2)                 2502
# _________________________________________________________________
# dense_4 (Dense)              (None, 1250)              3750
# _________________________________________________________________
# dense_5 (Dense)              (None, 2500)              3127500
# _________________________________________________________________
# dense_6 (Dense)              (None, 5000)              12505000
# _________________________________________________________________
# dense_7 (Dense)              (None, 10000)             50010000
# =================================================================
# Total params: 131,282,502
# Trainable params: 131,282,502
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/5
# 3387/3387 [==============================] - 34s 10ms/step - loss: 0.6905 - accuracy: 0.8919
# Epoch 2/5
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 3387/3387 [==============================] - 33s 10ms/step - loss: 0.2440 - accuracy: 0.9900
# Epoch 3/5
# 3387/3387 [==============================] - 33s 10ms/step - loss: 0.1117 - accuracy: 0.9881
# Epoch 4/5
# 3387/3387 [==============================] - 33s 10ms/step - loss: 0.0166 - accuracy: 0.9899
# Epoch 5/5
# 3387/3387 [==============================] - 32s 10ms/step - loss: 0.0086 - accuracy: 0.9906
# Dimensionality reduction from (3387, 10000) to (3387, 2) using Autoencoder model
# Starting to compute the K-means clustering algorithm..
# Model already exists and will be obtained from the cache path: Cache_kmeans_model.pl
# Run time of this operation is: 0.00 seconds
# ------------------------------------------------------------
# Top terms per cluster:
# cluster_to_label_map: {0: 'alt.atheism', 2: 'comp.graphics', 3: 'sci.space', 1: 'talk.religion.misc'}
# Cluster [0 alt.atheism]: god com jesus sandvik people bible don christian article just
# Cluster [2 comp.graphics]: space access nasa henry digex pat com toronto alaska gov
# Cluster [3 sci.space]: graphics university image thanks com ac posting host nntp files
# Cluster [1 talk.religion.misc]: keith sgi caltech com morality livesey objective moral solntze wpd
# ------------------------------------------------------------
# K-means prediction accuracy is: 0.36
# K-means prediction homogeniety score is: 0.55
# ------------------------------------------------------------
#
#
# Clustering Results:
# +----+----------------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                             |   predicted_clusters |   actual_clusters |
# |----+----------------------------------------------------------------------------------+----------------------+-------------------|
# |  1 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/54166        |                    0 |                 0 |
# |  9 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/84569  |                    0 |                 3 |
# | 11 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53784         |                    0 |                 0 |
# | 12 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/54184         |                    0 |                 0 |
# | 13 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/83506 |                    0 |                 3 |
# | 16 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53754        |                    0 |                 0 |
# | 20 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/84248  |                    0 |                 3 |
# | 24 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/83897 |                    0 |                 3 |
# | 30 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/83438 |                    0 |                 3 |
# | 31 | /root/scikit_learn_data/20news_home/20news-bydate-train/talk.religion.misc/84055 |                    0 |                 3 |
# +----+----------------------------------------------------------------------------------+----------------------+-------------------+
# +----+---------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                      |   predicted_clusters |   actual_clusters |
# |----+---------------------------------------------------------------------------+----------------------+-------------------|
# |  0 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51286 |                    1 |                 0 |
# |  5 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53522 |                    1 |                 0 |
# | 14 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53627  |                    1 |                 0 |
# | 21 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53212 |                    1 |                 0 |
# | 25 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53398  |                    1 |                 0 |
# | 28 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51310 |                    1 |                 0 |
# | 52 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51178 |                    1 |                 0 |
# | 58 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53120 |                    1 |                 0 |
# | 62 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53346  |                    1 |                 0 |
# | 65 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/53059 |                    1 |                 0 |
# +----+---------------------------------------------------------------------------+----------------------+-------------------+
# +----+-------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                    |   predicted_clusters |   actual_clusters |
# |----+-------------------------------------------------------------------------+----------------------+-------------------|
# |  2 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61019 |                    2 |                 2 |
# |  6 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61395  |                    2 |                 2 |
# |  7 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/59850 |                    2 |                 2 |
# | 10 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60223 |                    2 |                 2 |
# | 15 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61170 |                    2 |                 2 |
# | 19 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60861 |                    2 |                 2 |
# | 22 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61253  |                    2 |                 2 |
# | 23 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61017 |                    2 |                 2 |
# | 27 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60910 |                    2 |                 2 |
# | 32 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60770 |                    2 |                 2 |
# +----+-------------------------------------------------------------------------+----------------------+-------------------+
# +----+---------------------------------------------------------------------------------+----------------------+-------------------+
# |    | Docs                                                                            |   predicted_clusters |   actual_clusters |
# |----+---------------------------------------------------------------------------------+----------------------+-------------------|
# |  3 | /root/scikit_learn_data/20news_home/20news-bydate-test/talk.religion.misc/83968 |                    3 |                 3 |
# |  4 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/60921         |                    3 |                 2 |
# |  8 | /root/scikit_learn_data/20news_home/20news-bydate-train/sci.space/61004         |                    3 |                 2 |
# | 17 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38396     |                    3 |                 1 |
# | 18 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38424     |                    3 |                 1 |
# | 26 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38286     |                    3 |                 1 |
# | 29 | /root/scikit_learn_data/20news_home/20news-bydate-test/alt.atheism/53806        |                    3 |                 0 |
# | 36 | /root/scikit_learn_data/20news_home/20news-bydate-train/alt.atheism/51151       |                    3 |                 0 |
# | 41 | /root/scikit_learn_data/20news_home/20news-bydate-train/comp.graphics/38360     |                    3 |                 1 |
# | 45 | /root/scikit_learn_data/20news_home/20news-bydate-test/sci.space/61523          |                    3 |                 2 |
# +----+---------------------------------------------------------------------------------+----------------------+-------------------+
#
#
# dist.shape: (3387, 3387)
# Plotting the clusters in 2D space..
# <style>
#
# </style>
#
# <div id="fig_el8171406180762616808483630257"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el8171406180762616808483630257", {"width": 1224.0, "height": 648.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-49.44911125654295, 41.54985169397009], "ylim": [-63.503073319272346, 56.68191493915751], "xdomain": [-49.44911125654295, 41.54985169397009], "ydomain": [-63.503073319272346, 56.68191493915751], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el817140618076361728", "lines": [], "paths": [{"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "axes", "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "id": "el817140618052556672", "dasharray": "none", "alpha": 0.8, "facecolor": "#FFFFFF", "edgecolor": "#CCCCCC", "edgewidth": 1.0, "zorder": 1000000.0}], "markers": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el817140618052557008pts", "facecolor": "#1B9E77", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001], [-5.36780214952945, 3.117479224709121], [-4.242640687119286, 4.242640687119286], [-3.117479224709121, 5.36780214952945], [-1.5912186000000001, 6.0], [0.0, 6.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el817140618052556840pts", "facecolor": "#D95F02", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001], [-5.36780214952945, 3.117479224709121], [-4.242640687119286, 4.242640687119286], [-3.117479224709121, 5.36780214952945], [-1.5912186000000001, 6.0], [0.0, 6.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el817140618052558016pts", "facecolor": "#7570B3", "edgecolor": "none", "edgewidth": 1.0, "alpha": 1, "zorder": 2, "markerpath": [[[0.0, 6.0], [1.5912186000000001, 6.0], [3.117479224709121, 5.36780214952945], [4.242640687119286, 4.242640687119286], [5.36780214952945, 3.117479224709121], [6.0, 1.5912186000000001], [6.0, 0.0], [6.0, -1.5912186000000001], [5.36780214952945, -3.117479224709121], [4.242640687119286, -4.242640687119286], [3.117479224709121, -5.36780214952945], [1.5912186000000001, -6.0], [0.0, -6.0], [-1.5912186000000001, -6.0], [-3.117479224709121, -5.36780214952945], [-4.242640687119286, -4.242640687119286], [-5.36780214952945, -3.117479224709121], [-6.0, -1.5912186000000001], [-6.0, 0.0], [-6.0, 1.5912186000000001],  ...

# %%
import numpy as np
l = np.array([2,3,5,6,7,3,2,1,1,1])
l2 = range(10)
l3 = l[l2]
l3
# Out:
# array([2, 3, 5, 6, 7, 3, 2, 1, 1, 1])
